# %%
import pandas as pd
import numpy as np
from catboost import Pool, CatBoostRegressor
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import TimeSeriesSplit 
import optuna
import json
from sklearn.metrics import mean_absolute_error
#Load inn datasets
X_test  = pd.read_parquet('data/prepared_datasets/avg/no_duplicates/X_test.parquet')
X_train = pd.read_parquet('data/prepared_datasets/avg/no_duplicates/X_train.parquet')
y_train = pd.read_parquet('data/prepared_datasets/avg/no_duplicates/Y_train.parquet')
y_train_a = pd.read_parquet('data/prepared_datasets/avg/no_duplicates/Y_train_a.parquet')
y_train_b = pd.read_parquet('data/prepared_datasets/avg/no_duplicates/Y_train_b.parquet')
y_train_c = pd.read_parquet('data/prepared_datasets/avg/no_duplicates/Y_train_c.parquet')

# %%
def test_train_split(df):
    dates_2 = (df.index >= '2023-04-01') & (df.index <= '2023-04-15')
    dates_1 = (df.index >= '2021-05-01') & (df.index <= '2021-08-01')

    test_set = df[dates_1 | dates_2]

    training_set = df[~(dates_1 | dates_2)]

    X_train = training_set.drop("pv_measurement", axis=1)
    y_train = training_set['pv_measurement']

    X_test = test_set.drop("pv_measurement", axis=1)
    y_test = test_set['pv_measurement'] 

    
    
    return X_train, X_test, y_train, y_test

X_trainnew_a, X_test_new_a, y_train_new_a, y_test_a = test_train_split(pd.concat([X_train[X_train["location"] == "A"].drop("location", axis=1), y_train_a], axis=1))
X_train_new_b, X_test_new_b, y_train_new_b, y_test_b = test_train_split(pd.concat([X_train[X_train["location"] == "B"].drop("location", axis=1), y_train_b], axis=1))
X_train_new_c, X_test_new_c, y_train_new_c, y_test_c = test_train_split(pd.concat([X_train[X_train["location"] == "C"].drop("location", axis=1), y_train_c], axis=1))

X_train_loc_a, X_test_loc_a, y_train_loc_a, y_test_a = test_train_split(pd.concat([X_train[X_train["location"] == "A"], y_train_a], axis=1))
X_train_loc_b, X_test_loc_b, y_train_loc_b, y_test_b = test_train_split(pd.concat([X_train[X_train["location"] == "B"], y_train_b], axis=1))
X_train_loc_c, X_test_loc_c, y_train_loc_c, y_test_c = test_train_split(pd.concat([X_train[X_train["location"] == "C"], y_train_c], axis=1))


X_train_new = pd.concat([X_train_loc_a, X_train_loc_b, X_train_loc_c])
X_test_new = pd.concat([X_test_loc_a, X_test_loc_b, X_test_loc_c])
y_train_new = pd.concat([y_train_loc_a, y_train_loc_b, y_train_loc_c])
y_test = pd.concat([y_test_a, y_test_b, y_test_c])

# %%
import xgboost as xgb
from sklearn.metrics import mean_squared_error
import optuna

def objective(trial, X_train_new, y_train_new):
    params = {
        "n_estimators": trial.suggest_int("n_estimators", 1000, 3000),
        "verbosity": 0,
        "learning_rate": trial.suggest_float("learning_rate", 1e-3, 0.1, log=True),
        "max_depth": trial.suggest_int("max_depth", 1, 10),
        "subsample": trial.suggest_float("subsample", 0.05, 1.0),
        "colsample_bytree": trial.suggest_float("colsample_bytree", 0.05, 1.0),
        "min_child_weight": trial.suggest_int("min_child_weight", 1, 20),
        'eval_metric': 'mae'
    }

    model = xgb.XGBRegressor(**params)
    model.fit(X_train_new_b, y_train_new_b, verbose=300)
    pred = model.predict(X_test_new_b)
    MAE = mean_absolute_error(y_test_b, pred)
    return MAE
    
study = optuna.create_study(direction='minimize')
study.optimize(lambda trial: objective(trial, X_train_new_b, y_train_new_b), n_trials=70)
# Out:
# [I 2023-11-11 17:31:05,240] A new study created in memory with name: no-name-c7872f7a-db40-4f80-9cf4-186f22aa6f33
# [I 2023-11-11 17:31:09,657] Trial 0 finished with value: 74.88530299513819 and parameters: {'n_estimators': 1987, 'learning_rate': 0.058348716082063774, 'max_depth': 7, 'subsample': 0.7067041706619943, 'colsample_bytree': 0.06859857324926139, 'min_child_weight': 19}. Best is trial 0 with value: 74.88530299513819.
# [I 2023-11-11 17:31:11,153] Trial 1 finished with value: 76.3613868674005 and parameters: {'n_estimators': 1591, 'learning_rate': 0.023562886804277247, 'max_depth': 1, 'subsample': 0.9689407953925651, 'colsample_bytree': 0.6021851605719214, 'min_child_weight': 8}. Best is trial 0 with value: 74.88530299513819.
# [I 2023-11-11 17:31:17,646] Trial 2 finished with value: 66.9432723252984 and parameters: {'n_estimators': 2121, 'learning_rate': 0.012220792179720722, 'max_depth': 6, 'subsample': 0.3825012850937786, 'colsample_bytree': 0.8616898073385812, 'min_child_weight': 2}. Best is trial 2 with value: 66.9432723252984.
# [I 2023-11-11 17:31:21,039] Trial 3 finished with value: 70.23577948201427 and parameters: {'n_estimators': 2228, 'learning_rate': 0.009133714982576625, 'max_depth': 4, 'subsample': 0.35506458973728267, 'colsample_bytree': 0.09156506849251371, 'min_child_weight': 1}. Best is trial 2 with value: 66.9432723252984.
# [I 2023-11-11 17:31:46,110] Trial 4 finished with value: 77.96862957562446 and parameters: {'n_estimators': 1114, 'learning_rate': 0.002013368555915341, 'max_depth': 10, 'subsample': 0.6406558962806559, 'colsample_bytree': 0.9238571248392153, 'min_child_weight': 1}. Best is trial 2 with value: 66.9432723252984.
# [I 2023-11-11 17:31:47,654] Trial 5 finished with value: 75.87144913263064 and parameters: {'n_estimators': 1601, 'learning_rate': 0.017069182963268544, 'max_depth': 1, 'subsample': 0.317693232924892, 'colsample_bytree': 0.9118467004986595, 'min_child_weight': 7}. Best is trial 2 with value: 66.9432723252984.
# [I 2023-11-11 17:31:51,042] Trial 6 finished with value: 66.04813227610363 and parameters: {'n_estimators': 1617, 'learning_rate': 0.006422992881026409, 'max_depth': 5, 'subsample': 0.5565876223730986, 'colsample_bytree': 0.6869826214568406, 'min_child_weight': 17}. Best is trial 6 with value: 66.04813227610363.
# [I 2023-11-11 17:31:53,854] Trial 7 finished with value: 87.48309089719135 and parameters: {'n_estimators': 2833, 'learning_rate': 0.0015264965985078006, 'max_depth': 1, 'subsample': 0.792784039474863, 'colsample_bytree': 0.2936627149803659, 'min_child_weight': 18}. Best is trial 6 with value: 66.04813227610363.
# [I 2023-11-11 17:31:55,686] Trial 8 finished with value: 68.88123734563979 and parameters: {'n_estimators': 1495, 'learning_rate': 0.018620891305638074, 'max_depth': 2, 'subsample': 0.5766699644279225, 'colsample_bytree': 0.7530130617350702, 'min_child_weight': 1}. Best is trial 6 with value: 66.04813227610363.
# [I 2023-11-11 17:32:00,535] Trial 9 finished with value: 76.41932375858674 and parameters: {'n_estimators': 2965, 'learning_rate': 0.08775081509612334, 'max_depth': 4, 'subsample': 0.2229355784629829, 'colsample_bytree': 0.54514872338475, 'min_child_weight': 9}. Best is trial 6 with value: 66.04813227610363.
# [I 2023-11-11 17:32:05,224] Trial 10 finished with value: 67.24024107082002 and parameters: {'n_estimators': 1117, 'learning_rate': 0.0042201316587922285, 'max_depth': 8, 'subsample': 0.16270788562869082, 'colsample_bytree': 0.7079397529469922, 'min_child_weight': 14}. Best is trial 6 with value: 66.04813227610363.
# [I 2023-11-11 17:32:11,490] Trial 11 finished with value: 66.41199578149184 and parameters: {'n_estimators': 2247, 'learning_rate': 0.005545302630200737, 'max_depth': 6, 'subsample': 0.4682319429257087, 'colsample_bytree': 0.7897749785822192, 'min_child_weight': 13}. Best is trial 6 with value: 66.04813227610363.
# [I 2023-11-11 17:32:16,096] Trial 12 finished with value: 65.94909559696954 and parameters: {'n_estimators': 2558, 'learning_rate': 0.005306240872035004, 'max_depth': 4, 'subsample': 0.4825532032477152, 'colsample_bytree': 0.7328250797386645, 'min_child_weight': 14}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:32:21,493] Trial 13 finished with value: 66.37487008429542 and parameters: {'n_estimators': 2614, 'learning_rate': 0.0033868414849118683, 'max_depth': 4, 'subsample': 0.4995270379363218, 'colsample_bytree': 0.9966505584406997, 'min_child_weight': 16}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:32:25,177] Trial 14 finished with value: 77.68846754139844 and parameters: {'n_estimators': 2534, 'learning_rate': 0.001075699422763359, 'max_depth': 3, 'subsample': 0.5050995668280203, 'colsample_bytree': 0.6428344477702838, 'min_child_weight': 12}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:32:28,405] Trial 15 finished with value: 67.42067000526322 and parameters: {'n_estimators': 1844, 'learning_rate': 0.006972736605709703, 'max_depth': 5, 'subsample': 0.06016067613905535, 'colsample_bytree': 0.4804992811443214, 'min_child_weight': 16}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:32:38,993] Trial 16 finished with value: 66.7411918999495 and parameters: {'n_estimators': 2505, 'learning_rate': 0.0027886966964091784, 'max_depth': 8, 'subsample': 0.6105282512790482, 'colsample_bytree': 0.45951285013525084, 'min_child_weight': 20}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:32:41,026] Trial 17 finished with value: 67.8264197621666 and parameters: {'n_estimators': 1336, 'learning_rate': 0.005254777379182631, 'max_depth': 3, 'subsample': 0.4315456278252777, 'colsample_bytree': 0.6910180399271619, 'min_child_weight': 16}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:32:45,524] Trial 18 finished with value: 66.46881793767373 and parameters: {'n_estimators': 1883, 'learning_rate': 0.0028348733363797295, 'max_depth': 5, 'subsample': 0.7399007526277662, 'colsample_bytree': 0.8114162205182215, 'min_child_weight': 10}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:32:52,033] Trial 19 finished with value: 66.67931652612272 and parameters: {'n_estimators': 1704, 'learning_rate': 0.008074083312428888, 'max_depth': 7, 'subsample': 0.5815468013899973, 'colsample_bytree': 0.7458827482634656, 'min_child_weight': 6}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:33:02,950] Trial 20 finished with value: 67.41080690649899 and parameters: {'n_estimators': 2369, 'learning_rate': 0.005095759839401481, 'max_depth': 10, 'subsample': 0.28573388789469406, 'colsample_bytree': 0.6195836117936143, 'min_child_weight': 14}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:33:07,833] Trial 21 finished with value: 66.29730881794221 and parameters: {'n_estimators': 2635, 'learning_rate': 0.0035655215949910155, 'max_depth': 4, 'subsample': 0.48889653742517364, 'colsample_bytree': 0.9325084599926659, 'min_child_weight': 17}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:33:11,774] Trial 22 finished with value: 67.3968966692326 and parameters: {'n_estimators': 2741, 'learning_rate': 0.0036343093230709004, 'max_depth': 3, 'subsample': 0.42593660528025745, 'colsample_bytree': 0.8419086646469387, 'min_child_weight': 17}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:33:18,486] Trial 23 finished with value: 66.27723169673982 and parameters: {'n_estimators': 2938, 'learning_rate': 0.0021941003297671338, 'max_depth': 5, 'subsample': 0.5212330760152301, 'colsample_bytree': 0.9925358835807118, 'min_child_weight': 15}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:33:25,456] Trial 24 finished with value: 66.2135376847603 and parameters: {'n_estimators': 2941, 'learning_rate': 0.00206880242743498, 'max_depth': 5, 'subsample': 0.5660989010639393, 'colsample_bytree': 0.9678445214814668, 'min_child_weight': 12}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:33:33,550] Trial 25 finished with value: 66.44761161831983 and parameters: {'n_estimators': 2767, 'learning_rate': 0.0018449248813485358, 'max_depth': 6, 'subsample': 0.41702533743618986, 'colsample_bytree': 0.8387731390297446, 'min_child_weight': 12}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:33:44,882] Trial 26 finished with value: 71.42230409230902 and parameters: {'n_estimators': 2444, 'learning_rate': 0.0011736930172682972, 'max_depth': 7, 'subsample': 0.6532294000967118, 'colsample_bytree': 0.7078477206325565, 'min_child_weight': 11}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:33:48,693] Trial 27 finished with value: 71.13004839527747 and parameters: {'n_estimators': 2995, 'learning_rate': 0.0024413429354457447, 'max_depth': 2, 'subsample': 0.5282158338875855, 'colsample_bytree': 0.7891203501444273, 'min_child_weight': 5}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:33:52,083] Trial 28 finished with value: 66.09086392451509 and parameters: {'n_estimators': 1429, 'learning_rate': 0.006810424936933219, 'max_depth': 5, 'subsample': 0.5571223881758813, 'colsample_bytree': 0.8947137864161212, 'min_child_weight': 14}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:33:55,737] Trial 29 finished with value: 66.88515055564282 and parameters: {'n_estimators': 1318, 'learning_rate': 0.01189997732958699, 'max_depth': 6, 'subsample': 0.7184035198112317, 'colsample_bytree': 0.8792424810396041, 'min_child_weight': 19}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:33:57,808] Trial 30 finished with value: 67.48205642242758 and parameters: {'n_estimators': 1353, 'learning_rate': 0.006590049153067123, 'max_depth': 3, 'subsample': 0.6573088930238792, 'colsample_bytree': 0.8795210199553603, 'min_child_weight': 14}. Best is trial 12 with value: 65.94909559696954.
# [I 2023-11-11 17:34:02,562] Trial 31 finished with value: 65.70471258577513 and parameters: {'n_estimators': 1993, 'learning_rate': 0.004111496467313203, 'max_depth': 5, 'subsample': 0.5581237337025204, 'colsample_bytree': 0.9570585302525744, 'min_child_weight': 12}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:34:10,134] Trial 32 finished with value: 66.05028586402835 and parameters: {'n_estimators': 2024, 'learning_rate': 0.004677062235888707, 'max_depth': 7, 'subsample': 0.5466610230234965, 'colsample_bytree': 0.931204307884007, 'min_child_weight': 10}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:34:17,872] Trial 33 finished with value: 66.65710407820707 and parameters: {'n_estimators': 2037, 'learning_rate': 0.004937806426800919, 'max_depth': 7, 'subsample': 0.3939205431395655, 'colsample_bytree': 0.8279458923685435, 'min_child_weight': 9}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:34:31,738] Trial 34 finished with value: 68.05045467158193 and parameters: {'n_estimators': 1806, 'learning_rate': 0.010140015034495152, 'max_depth': 9, 'subsample': 0.6077134347901202, 'colsample_bytree': 0.9472553922725119, 'min_child_weight': 10}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:34:54,702] Trial 35 finished with value: 66.42914441825822 and parameters: {'n_estimators': 1991, 'learning_rate': 0.0041700352459273764, 'max_depth': 8, 'subsample': 0.4771798055983595, 'colsample_bytree': 0.7631921031749628, 'min_child_weight': 4}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:35:06,892] Trial 36 finished with value: 66.96791133836972 and parameters: {'n_estimators': 2143, 'learning_rate': 0.009051767119659448, 'max_depth': 6, 'subsample': 0.44571966011022085, 'colsample_bytree': 0.930523136274953, 'min_child_weight': 8}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:35:12,393] Trial 37 finished with value: 67.93418323136247 and parameters: {'n_estimators': 1656, 'learning_rate': 0.027262437206329343, 'max_depth': 4, 'subsample': 0.6802471764853881, 'colsample_bytree': 0.8479086505357749, 'min_child_weight': 13}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:35:26,744] Trial 38 finished with value: 67.09634578473653 and parameters: {'n_estimators': 2268, 'learning_rate': 0.0063181884317030975, 'max_depth': 7, 'subsample': 0.771974915250659, 'colsample_bytree': 0.8909408657481314, 'min_child_weight': 11}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:35:35,925] Trial 39 finished with value: 66.04305348694984 and parameters: {'n_estimators': 2141, 'learning_rate': 0.003078017913440844, 'max_depth': 5, 'subsample': 0.8285694833443769, 'colsample_bytree': 0.6625855010488015, 'min_child_weight': 18}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:35:40,547] Trial 40 finished with value: 71.93102821977564 and parameters: {'n_estimators': 2153, 'learning_rate': 0.0030984823395672077, 'max_depth': 2, 'subsample': 0.8528125129194898, 'colsample_bytree': 0.581151959641568, 'min_child_weight': 19}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:35:46,362] Trial 41 finished with value: 66.39521158883618 and parameters: {'n_estimators': 1945, 'learning_rate': 0.004504814435049643, 'max_depth': 4, 'subsample': 0.9893467378294878, 'colsample_bytree': 0.65366774552448, 'min_child_weight': 20}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:35:52,459] Trial 42 finished with value: 66.29759809231136 and parameters: {'n_estimators': 1730, 'learning_rate': 0.003885146143202562, 'max_depth': 5, 'subsample': 0.36745389475548135, 'colsample_bytree': 0.7354077158727745, 'min_child_weight': 18}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:36:06,359] Trial 43 finished with value: 66.21274425534266 and parameters: {'n_estimators': 2326, 'learning_rate': 0.002650246872088133, 'max_depth': 6, 'subsample': 0.6106119025978992, 'colsample_bytree': 0.6684447588697364, 'min_child_weight': 13}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:36:13,524] Trial 44 finished with value: 66.25133774508734 and parameters: {'n_estimators': 2024, 'learning_rate': 0.0057376645781153915, 'max_depth': 4, 'subsample': 0.840960292383101, 'colsample_bytree': 0.7654155096074815, 'min_child_weight': 18}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:36:20,818] Trial 45 finished with value: 66.38391802801253 and parameters: {'n_estimators': 1565, 'learning_rate': 0.004575350651115569, 'max_depth': 6, 'subsample': 0.9215277292502704, 'colsample_bytree': 0.5893195633776486, 'min_child_weight': 15}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:36:24,969] Trial 46 finished with value: 69.92647750727461 and parameters: {'n_estimators': 1026, 'learning_rate': 0.0032467323272241523, 'max_depth': 5, 'subsample': 0.5388999242360406, 'colsample_bytree': 0.7174794430358419, 'min_child_weight': 17}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:36:31,391] Trial 47 finished with value: 66.39565722414385 and parameters: {'n_estimators': 2111, 'learning_rate': 0.007826345416647588, 'max_depth': 4, 'subsample': 0.6860166412690661, 'colsample_bytree': 0.8029833761506686, 'min_child_weight': 15}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:36:45,076] Trial 48 finished with value: 66.9019660224953 and parameters: {'n_estimators': 1909, 'learning_rate': 0.005614856795653264, 'max_depth': 8, 'subsample': 0.6322745004891475, 'colsample_bytree': 0.6760381969731607, 'min_child_weight': 8}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:36:49,635] Trial 49 finished with value: 67.70742606931181 and parameters: {'n_estimators': 1798, 'learning_rate': 0.0039621942818193435, 'max_depth': 3, 'subsample': 0.46890674195892257, 'colsample_bytree': 0.997648910462387, 'min_child_weight': 9}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:37:04,009] Trial 50 finished with value: 68.34870123591416 and parameters: {'n_estimators': 2373, 'learning_rate': 0.001625892126405912, 'max_depth': 7, 'subsample': 0.3375702497723586, 'colsample_bytree': 0.9123742336235614, 'min_child_weight': 16}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:37:09,847] Trial 51 finished with value: 65.98939237058188 and parameters: {'n_estimators': 1432, 'learning_rate': 0.006281296392855204, 'max_depth': 5, 'subsample': 0.5585100821180796, 'colsample_bytree': 0.8955179241864007, 'min_child_weight': 14}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:37:16,009] Trial 52 finished with value: 65.84545342146512 and parameters: {'n_estimators': 1482, 'learning_rate': 0.004755537716042132, 'max_depth': 5, 'subsample': 0.5691583267647706, 'colsample_bytree': 0.956518123991245, 'min_child_weight': 11}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:37:23,211] Trial 53 finished with value: 66.7702202281732 and parameters: {'n_estimators': 1501, 'learning_rate': 0.0032403947195358647, 'max_depth': 5, 'subsample': 0.613007632369616, 'colsample_bytree': 0.9653488147078282, 'min_child_weight': 12}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:37:27,829] Trial 54 finished with value: 66.02348400759882 and parameters: {'n_estimators': 1234, 'learning_rate': 0.00803265116745874, 'max_depth': 4, 'subsample': 0.5074062233470417, 'colsample_bytree': 0.8648571450994255, 'min_child_weight': 13}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:37:31,963] Trial 55 finished with value: 66.05845548748106 and parameters: {'n_estimators': 1163, 'learning_rate': 0.007961838891600341, 'max_depth': 4, 'subsample': 0.4916465102520908, 'colsample_bytree': 0.8665124370665063, 'min_child_weight': 13}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:37:35,696] Trial 56 finished with value: 67.51136269389448 and parameters: {'n_estimators': 1284, 'learning_rate': 0.005823219300760999, 'max_depth': 3, 'subsample': 0.5265676164167622, 'colsample_bytree': 0.9071975230609173, 'min_child_weight': 11}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:37:40,103] Trial 57 finished with value: 72.03180157744988 and parameters: {'n_estimators': 1185, 'learning_rate': 0.002618692879235921, 'max_depth': 4, 'subsample': 0.6006014531667575, 'colsample_bytree': 0.8076417248365128, 'min_child_weight': 15}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:37:46,119] Trial 58 finished with value: 66.5139495735357 and parameters: {'n_estimators': 1424, 'learning_rate': 0.003829836736928965, 'max_depth': 5, 'subsample': 0.453800063481824, 'colsample_bytree': 0.966217282245878, 'min_child_weight': 12}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:37:51,154] Trial 59 finished with value: 66.11570276811318 and parameters: {'n_estimators': 1235, 'learning_rate': 0.005176160256911955, 'max_depth': 5, 'subsample': 0.5735673916367826, 'colsample_bytree': 0.8638570987437142, 'min_child_weight': 14}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:37:56,050] Trial 60 finished with value: 66.29187074655601 and parameters: {'n_estimators': 1001, 'learning_rate': 0.006734601678272845, 'max_depth': 6, 'subsample': 0.4919649707007576, 'colsample_bytree': 0.8339727303874498, 'min_child_weight': 11}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:38:00,541] Trial 61 finished with value: 66.04663211124924 and parameters: {'n_estimators': 1494, 'learning_rate': 0.009086940333738998, 'max_depth': 4, 'subsample': 0.5765949174865642, 'colsample_bytree': 0.7793435584681015, 'min_child_weight': 13}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:38:04,938] Trial 62 finished with value: 65.92859772832105 and parameters: {'n_estimators': 1484, 'learning_rate': 0.010095969261535151, 'max_depth': 4, 'subsample': 0.5120664565728504, 'colsample_bytree': 0.9198011433489283, 'min_child_weight': 13}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:38:11,582] Trial 63 finished with value: 66.57163340932831 and parameters: {'n_estimators': 1443, 'learning_rate': 0.011411503901346326, 'max_depth': 5, 'subsample': 0.5138337200236794, 'colsample_bytree': 0.9114309498976412, 'min_child_weight': 12}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:38:15,843] Trial 64 finished with value: 67.0164683338783 and parameters: {'n_estimators': 1566, 'learning_rate': 0.007570017308067218, 'max_depth': 3, 'subsample': 0.38928219729559504, 'colsample_bytree': 0.962496212086438, 'min_child_weight': 14}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:38:23,179] Trial 65 finished with value: 66.84680430971748 and parameters: {'n_estimators': 2571, 'learning_rate': 0.014825337686821337, 'max_depth': 4, 'subsample': 0.44909917542411704, 'colsample_bytree': 0.8643802783891762, 'min_child_weight': 13}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:38:29,263] Trial 66 finished with value: 66.10740913318419 and parameters: {'n_estimators': 1381, 'learning_rate': 0.004420427034667563, 'max_depth': 5, 'subsample': 0.5465996217956713, 'colsample_bytree': 0.9956922424183442, 'min_child_weight': 10}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:38:32,443] Trial 67 finished with value: 67.70359768422787 and parameters: {'n_estimators': 1087, 'learning_rate': 0.0061169522319153855, 'max_depth': 3, 'subsample': 0.5042429746507969, 'colsample_bytree': 0.9433590484690291, 'min_child_weight': 16}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:38:37,518] Trial 68 finished with value: 65.94680396468293 and parameters: {'n_estimators': 1641, 'learning_rate': 0.00978121056432755, 'max_depth': 4, 'subsample': 0.41938101767152275, 'colsample_bytree': 0.8853257100949296, 'min_child_weight': 15}. Best is trial 31 with value: 65.70471258577513.
# [I 2023-11-11 17:38:42,187] Trial 69 finished with value: 69.39924143328041 and parameters: {'n_estimators': 1682, 'learning_rate': 0.009281623213292903, 'max_depth': 2, 'subsample': 0.4184608214700068, 'colsample_bytree': 0.9061077309471306, 'min_child_weight': 15}. Best is trial 31 with value: 65.70471258577513.
